# %%
# Problem Selection Process - Dublin Bus Project

# Objective:
# Reduce an initial set of 18 problem clusters into 3 priority problem candidates
# using a simple, transparent, criteria-based selection method.

# %%
initial_problem_clusters = [
    "Time & Reliability Issues",
    "Ghost Buses / Information Failure",
    "Routes & System Complexity",
    "Connections & Integration",
    "Stops & Infrastructure",
    "Digital Experience & Apps",
    "Payment System Issues",
    "Internal Operations",
    "Safety & Behaviour",
    "Onboard Experience",
    "Speed & Efficiency",
    "Events & Urban Context",
    "Data & Information Management",
    "Communication & Transparency",
    "General User Experience",
    "System vs Reality Contradictions",
    "Connectivity & Spatial Imbalance",
    "Meta Problem: Uncertainty Management Failure"
]

len(initial_problem_clusters)
# Out:
# 18

# %%
import pandas as pd

df_initial = pd.DataFrame({
    "original_cluster": initial_problem_clusters
})

df_initial.index = df_initial.index + 1
df_initial
# Out:
#                                 original_cluster
# 1                      Time & Reliability Issues
# 2              Ghost Buses / Information Failure
# 3                     Routes & System Complexity
# 4                      Connections & Integration
# 5                         Stops & Infrastructure
# 6                      Digital Experience & Apps
# 7                          Payment System Issues
# 8                            Internal Operations
# 9                             Safety & Behaviour
# 10                            Onboard Experience
# 11                            Speed & Efficiency
# 12                        Events & Urban Context
# 13                 Data & Information Management
# 14                  Communication & Transparency
# 15                       General User Experience
# 16              System vs Reality Contradictions
# 17              Connectivity & Spatial Imbalance
# 18  Meta Problem: Uncertainty Management Failure
